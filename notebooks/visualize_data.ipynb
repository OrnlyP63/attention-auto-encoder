# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2
from utility.data_visualization import plot, plot2
from utility.data_processing import set_time_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
for ticker in ['btc', 'eth', 'doge', 'xrp', 'ada']:
  currency_metrics = pd.read_csv(f'../data/{ticker}_metrics_5_years.csv')
  set_metrics = set_time_data(currency_metrics)
  plot(set_metrics, ticker)

# %%
for ticker in ['btc', 'eth', 'doge', 'xrp', 'ada']:
  currency_metrics = pd.read_csv(f'../data/{ticker}_metrics_5_years.csv')
  set_metrics = set_time_data(currency_metrics)
  plot2(set_metrics, ticker)
