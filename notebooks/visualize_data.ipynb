# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2
from utility.data_visualization import plot
from utility.data_processing import set_time_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
for ticker in ['btc', 'eth', 'doge', 'xrp', 'usdt']:
  currency_metrics = pd.read_csv(f'../data/{ticker}_metrics_5_years.csv')
  set_metrics = set_time_data(currency_metrics)
  plot(set_metrics, ticker)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       2 currency_metrics = pd.read_csv(f'../data/{ticker}_metrics_5_years.csv')
#       3 set_metrics = set_time_data(currency_metrics)
# ----> 4 plot(set_metrics, ticker)
#
# File c:\Users\ideapad 330\Desktop\auto-encoder\attention-auto-encoder\notebooks\utility\data_visualization.py:15, in plot(df, ticker)
#      13 fig, axes = plt.subplots(3, 1, figsize=(12, 10), sharex=True)  # 3 rows, 1 column
#      14 for col in ['CapMVRVCur', 'NVTAdj', 'returns']:
# ---> 15   sns.lineplot(x="time", y=col, data=df, ax=axes[0], color="royalblue", label=col + f' of {name}')
#      17 # Set common x-axis label and title
#      18 axes[-1].set_xlabel("Date", fontsize=14)
#
# ...
